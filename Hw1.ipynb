# %%
from pandas import Series, DataFrame
import pandas as pd
orig_data = pd.read_csv('Data/Train_rev1.csv',
                        dtype=unicode)

# %%
orig_data
# Out:
#               Id                                              Title  \
# 0       12612628                        Engineering Systems Analyst
# 1       12612830                            Stress Engineer Glasgow
# 2       12612844                   Modelling and simulation analyst
# 3       12613049  Engineering Systems Analyst / Mathematical Mod...
# 4       12613647         Pioneer, Miser Engineering Systems Analyst
# 5       13179816         Engineering Systems Analyst Water Industry
# 6       14131336          Senior Subsea Pipeline Integrity Engineer
# 7       14663196  RECRUITMENT CONSULTANT  INDUSTRIAL / COMMERCIA...
# 8       14663197  RECRUITMENT CONSULTANT  CONSTRUCTION / TECHNIC...
# 9       15395797                             Subsea Cables Engineer
# 10      19047429            Trainee Mortgage Advisor  East Midlands
# 11      20199757                   PROJECT ENGINEER, PHARMACEUTICAL
# 12      20638787                Principal Composite Stress Engineer
# ...

# %%
jobs_sample = orig_data.sample(1000)

# %%
jobs_sample
# Out:
#               Id                                              Title  \
# 82810   69042381                                Testing Coordinator
# 183438  71624825                           Business Account Manager
# 153686  70809071                                WAREHOUSE OPERATIVE
# 116089  69777189                       Multi Skilled Shift Engineer
# 92351   69173550                   Senior EIA Consultant  Edinburgh
# 188532  71692970                 Campaign Marketing Manager  Retail
# 164562  71275601   HEAD CHEF OXFORDSHIRE VILLAGE PUB (FREE LIVE IN)
# 132062  70210397                      Pensions Valuation Accountant
# 82524   69040286           Business Solutions Architect  Oracle ERP
# 151987  70770693                                          Developer
# 173382  71430396                   Employer Partnership Coordinator
# 106502  69591871                              B2B Account Executive
# 119321  69852686        Trainee Sales Assistant  Film Game Packages
# ...

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
import nltk

# %%
from nltk.util import ngrams
from collections import Counter

# %%
jobs_sample['tokenized_strip'] = jobs_sample.apply(lambda row: row['FullDescription'].decode('utf-8').strip(),axis=1)
jobs_sample['tokenized'] = jobs_sample.apply(lambda row: nltk.word_tokenize(row['tokenized_strip']),axis=1)
